# %% [markdown]
# # Dataframes: Used to store heterogenous data

# %%
import numpy as np
import pandas as pd
a = {"name":["sommy", "swayam"], "age":[4, 19]}
dict = pd.DataFrame(a)
dict
# Out:
#      name  age
# 0   sommy    4
# 1  swayam   19

# %%
dict.to_csv('friends.csv')

# %%
dict.to_csv('friends_no_index.csv', index=False)

# %%
dict.head(1)
# Out:
#     name  age
# 0  sommy    4

# %%
dict.tail(1)
# Out:
#      name  age
# 1  swayam   19

# %%
dict.describe()
# Out:
#              age
# count   2.000000
# mean   11.500000
# std    10.606602
# min     4.000000
# 25%     7.750000
# 50%    11.500000
# 75%    15.250000
# max    19.000000

# %%
read = pd.read_csv('reading.csv')

# %%
read
# Out:
#    Unnamed: 0    Name  Age  Roll_no  Grade
# 0           0  Swayam   19       10     13
# 1           1   Sommy    3        1     13
# 2           2   Subin   19       10     13
# 3           3   Pommy   19       10     13

# %%
read.Age[1] = 3
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_8828\2621550738.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read.Age[1] = 3

# %%
read
# Out:
#    Unnamed: 0    Name  Age  Roll_no  Grade
# 0           0  Swayam   19       10     13
# 1           1   Sommy    3        1     13
# 2           2   Subin   19       10     13
# 3           3   Pommy   19       10     13

# %%
read.Roll_no[1] = 1
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_8828\2837356315.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read.Roll_no[1] = 1

# %%
read
# Out:
#    Unnamed: 0    Name  Age  Roll_no  Grade
# 0           0  Swayam   19       10     13
# 1           1   Sommy    3        1     13
# 2           2   Subin   19       10     13
# 3           3   Pommy   19       10     13

# %%
read.to_csv('reading.csv')

# %%
read
# Out:
#    Unnamed: 0    Name  Age  Roll_no  Grade
# 0           0  Swayam   19       10     13
# 1           1   Sommy    3        1     13
# 2           2   Subin   19       10     13
# 3           3   Pommy   19       10     13

# %%
read.index=['First', 'second', 'third', 'fourth']

# %%
read
# Out:
#         Unnamed: 0    Name  Age  Roll_no  Grade
# First            0  Swayam   19       10     13
# second           1   Sommy    3        1     13
# third            2   Subin   19       10     13
# fourth           3   Pommy   19       10     13

# %%
pd.read_csv('reading.csv')
# Out:
#    Unnamed: 0.1  Unnamed: 0    Name  Age  Roll_no  Grade
# 0             0           0  Swayam   19       10     13
# 1             1           1   Sommy    3        1     13
# 2             2           2   Subin   19       10     13
# 3             3           3   Pommy   19       10     13

# %%
pd.read_csv('reading.csv')
# Out:
#    Unnamed: 0.1  Unnamed: 0    Name  Age  Roll_no  Grade
# 0             0           0  Swayam   19       10     13
# 1             1           1   Sommy    3        1     13
# 2             2           2   Subin   19       10     13
# 3             3           3   Pommy   19       10     13

# %%
read
# Out:
#         Unnamed: 0    Name  Age  Roll_no  Grade
# First            0  Swayam   19       10     13
# second           1   Sommy    3        1     13
# third            2   Subin   19       10     13
# fourth           3   Pommy   19       10     13

# %%
read.to_csv('reading.csv')

# %%
read
# Out:
#         Unnamed: 0    Name  Age  Roll_no  Grade
# First            0  Swayam   19       10     13
# second           1   Sommy    3        1     13
# third            2   Subin   19       10     13
# fourth           3   Pommy   19       10     13

# %%
read.to_csv('reading.csv', index=False)

# %%
read
# Out:
#         Unnamed: 0    Name  Age  Roll_no  Grade
# First            0  Swayam   19       10     13
# second           1   Sommy    3        1     13
# third            2   Subin   19       10     13
# fourth           3   Pommy   19       10     13

# %%
read = pd.read_csv('reading.csv')

# %%
read
# Out:
#    Unnamed: 0    Name  Age  Roll_no  Grade
# 0           0  Swayam   19       10     13
# 1           1   Sommy    3        1     13
# 2           2   Subin   19       10     13
# 3           3   Pommy   19       10     13

# %%
read.to_csv('reading.csv', index=False)

# %%
read
# Out:
#    Unnamed: 0    Name  Age  Roll_no  Grade
# 0           0  Swayam   19       10     13
# 1           1   Sommy    3        1     13
# 2           2   Subin   19       10     13
# 3           3   Pommy   19       10     13

# %%
read.head(1)
# Out:
#    Unnamed: 0    Name  Age  Roll_no  Grade
# 0           0  Swayam   19       10     13

# %%
read.tail(2)
# Out:
#    Unnamed: 0   Name  Age  Roll_no  Grade
# 2           2  Subin   19       10     13
# 3           3  Pommy   19       10     13

# %%
read1 = read

# %%
read1
# Out:
#    Unnamed: 0    Name  Age  Roll_no  Grade
# 0           0  Swayam   19       10     13
# 1           1   Sommy    3        1     13
# 2           2   Subin   19       10     13
# 3           3   Pommy   19       10     13

# %%
read1.to_csv('reading1.csv', index=False)

# %%
pd.read_csv('reading1.csv')
# Out:
#    Unnamed: 0    Name  Age  Roll_no  Grade
# 0           0  Swayam   19       10     13
# 1           1   Sommy    3        1     13
# 2           2   Subin   19       10     13
# 3           3   Pommy   19       10     13

# %% [markdown]
# # Series: Stores homogeneous data

# %%
series = pd.Series(np.random.rand(20))

# %%
series
# Out:
# 0     0.980679
# 1     0.645652
# 2     0.430673
# 3     0.262897
# 4     0.352215
# 5     0.623714
# 6     0.741399
# 7     0.564981
# 8     0.201975
# 9     0.683311
# 10    0.992035
# 11    0.127404
# 12    0.482048
# 13    0.620068
# 14    0.696645
# 15    0.239064
# 16    0.510854
# 17    0.396000
# 18    0.058004
# 19    0.781695
# dtype: float64

# %%
series1 = pd.Series(np.random.rand(20))

# %%
series3 = series + series1

# %%
series3
# Out:
# 0     1.575100
# 1     1.502102
# 2     0.974819
# 3     1.226922
# 4     0.355268
# 5     0.778821
# 6     1.106622
# 7     1.239558
# 8     0.226437
# 9     0.686831
# 10    1.727611
# 11    0.238526
# 12    0.899726
# 13    0.774754
# 14    1.132459
# 15    0.344595
# 16    0.821503
# 17    0.686045
# 18    0.789170
# 19    1.559902
# dtype: float64

# %%
type(series3)
# Out:
# pandas.core.series.Series

# %%
type(read)
# Out:
# pandas.core.frame.DataFrame

# %%
type(dict)
# Out:
# pandas.core.frame.DataFrame

# %%
type(a)
# Out:
# dict

# %%
b=[1,2,3]

# %%
type(b)
# Out:
# list

# %%
newdf = pd.DataFrame(np.random.rand(320,10),index = np.arange(320))

# %%
newdf
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.265181  0.589775  0.157341  0.809486  0.265164  0.951230  0.865672
# 1    0.993055  0.816023  0.771108  0.435114  0.674062  0.933069  0.397244
# 2    0.878181  0.407539  0.277625  0.470148  0.915559  0.789691  0.614388
# 3    0.602740  0.921677  0.327032  0.223274  0.222496  0.822141  0.583255
# 4    0.179375  0.368591  0.813978  0.132293  0.724275  0.754739  0.865419
# ..        ...       ...       ...       ...       ...       ...       ...
# 315  0.225751  0.781242  0.410185  0.994910  0.900653  0.457395  0.985627
# 4  0.618278  0.636245  0.461939

# %%
newdf1.loc[[0,4],[3,5]]
# Out:
#           3         5
# 0  0.038762  0.345344
# 4  0.080220  0.470849

# %%
newdf2["a"]
# Out:
# 1           0.3
# 2      0.993055
# 3      0.878181
# 4       0.60274
# 5      0.179375
#          ...
# 316    0.225751
# 317    0.552878
# 318    0.288015
# 319    0.433425
# 320    0.047887
# Name: a, Length: 320, dtype: object

# %%
newdf2.loc[(newdf2["f"]>0.9) & (newdf2["b"]>0.9)]
# Out:
#             a         b         c         d         e         f         g  \
# 146   0.85391  0.970710  0.038433  0.920926  0.805090  0.903543  0.266523
# 171  0.642637  0.944074  0.592508  0.445289  0.868612  0.907441  0.834016
# 255  0.582824  0.991490  0.461556  0.375789  0.966921  0.908373  0.275698
#
#             h         i         j
# 146  0.456002  0.120858  0.375780
# 171  0.266763  0.528383  0.362500
# 255  0.195620  0.979078  0.484666

# %%
newdf1.loc[0,1]
# Out:
# 0.20350318474980256

# %%
newdf1.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.684630  0.203503  0.304648  0.038762  0.048516  0.345344  0.766243
# 1  0.069203  0.799301  0.093215  0.355038  0.611186  0.645127  0.079983
# 2  0.634936  0.373482  0.819174  0.490632  0.278494  0.920330  0.723835
# 3  0.385077  0.191374  0.819081  0.775943  0.819481  0.878292  0.245126
# 4  0.740371  0.736357  0.595298  0.080220  0.465925  0.470849  0.843878
#
#           7         8         9
# 0  0.594754  0.909480  0.564130
# 1  0.275743  0.244352  0.386590
# 2  0.420100  0.262422  0.593523
# 3  0.670843  0.249960  0.657519
# 4  0.618278  0.636245  0.461939

# %%
newdf3.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.991186  0.327043  0.106727  0.478752  0.232095  0.344368  0.965450
# 1  0.472846  0.719162  0.192463  0.617820  0.886119  0.328003  0.341951
# 2  0.832383  0.859490  0.020957  0.453814  0.847488  0.459884  0.848985
# 3  0.851281  0.102399  0.608728  0.598402  0.829386  0.370834  0.186377
# 4  0.663352  0.232065  0.406113  0.160818  0.563249  0.717042  0.774257
#
#           7         8         9
# 0  0.288435  0.574476  0.914679
# 1  0.811563  0.357417  0.346404
# 2  0.150080  0.104637  0.696309
# 3  0.135616  0.688776  0.177635
# 4  0.397669  0.659784  0.685581

# %%
newdf3.drop([0,1,2,3], axis=1)
# Out:
#           4         5         6         7         8         9
# 0  0.232095  0.344368  0.965450  0.288435  0.574476  0.914679
# 1  0.886119  0.328003  0.341951  0.811563  0.357417  0.346404
# 2  0.847488  0.459884  0.848985  0.150080  0.104637  0.696309
# 3  0.829386  0.370834  0.186377  0.135616  0.688776  0.177635
# 4  0.563249  0.717042  0.774257  0.397669  0.659784  0.685581
# 5  0.284650  0.826679  0.520557  0.453604  0.688086  0.447407
# 6  0.709923  0.250530  0.667946  0.641998  0.081825  0.776191
# 7  0.017677  0.199687  0.938494  0.969528  0.511936  0.922335
# 8  0.405649  0.715562  0.718081  0.068290  0.592686  0.358632
# 9  0.016719  0.340645  0.651333  0.283221  0.939302  0.784676

# %%
newdf2.head()
# Out:
#           a         b            c         d         e         f         g  \
# 1       0.3  0.589775     0.157341  0.809486  0.265164  0.951230  0.865672
# 2  0.993055  0.816023  2389.000000  0.435114  0.674062  0.933069  0.397244
# 3  0.878181  0.407539     0.277625  0.470148  0.915559  0.789691  0.614388
# 4   0.60274  0.921677     0.327032  0.223274  0.222496  0.822141  0.583255
# 5  0.179375  0.368591     0.813978  0.132293  0.724275  0.754739  0.865419
#
#           h         i         j
# 1  0.055177  0.869342  0.809105
# 2  0.643524  0.579457  0.835099
# 3  0.695804  0.627689  0.134094
# 4  0.855693  0.762797  0.263273
# 5  0.115947  0.173696  0.550884

# %%
newdf2.reset_index()
# Out:
#      index         a         b            c         d         e         f  \
# 0        1       0.3  0.589775     0.157341  0.809486  0.265164  0.951230
# 1        2  0.993055  0.816023  2389.000000  0.435114  0.674062  0.933069
# 2        3  0.878181  0.407539     0.277625  0.470148  0.915559  0.789691
# 3        4   0.60274  0.921677     0.327032  0.223274  0.222496  0.822141
# 4        5  0.179375  0.368591     0.813978  0.132293  0.724275  0.754739
# ..     ...       ...       ...          ...       ...       ...       ...
# 315    316  0.225751  0.781242     0.410185  0.994910  0.900653  0.457395
# 316    317  0.552878  0.624007     0.919886  0.343476  0.091060  0.035843
# 317    318  0.288015  0.046701     0.313751  0.265766  0.757930  0.688525
# 318    319  0.433425  0.329384     0.649478  0.510130  0.258696  0.769901
# 319    320  0.047887  0.530913     0.529743  0.201659  0.159088  0.881591
#
#             g         h         i         j
# ...

# %%
newdf2.reset_index(drop=True)
# Out:
#             a         b            c         d         e         f         g  \
# 0         0.3  0.589775     0.157341  0.809486  0.265164  0.951230  0.865672
# 1    0.993055  0.816023  2389.000000  0.435114  0.674062  0.933069  0.397244
# 2    0.878181  0.407539     0.277625  0.470148  0.915559  0.789691  0.614388
# 3     0.60274  0.921677     0.327032  0.223274  0.222496  0.822141  0.583255
# 4    0.179375  0.368591     0.813978  0.132293  0.724275  0.754739  0.865419
# ..        ...       ...          ...       ...       ...       ...       ...
# 315  0.225751  0.781242     0.410185  0.994910  0.900653  0.457395  0.985627
# 316  0.552878  0.624007     0.919886  0.343476  0.091060  0.035843  0.706981
# 317  0.288015  0.046701     0.313751  0.265766  0.757930  0.688525  0.383174
# 318  0.433425  0.329384     0.649478  0.510130  0.258696  0.769901  0.307465
# 319  0.047887  0.530913     0.529743  0.201659  0.159088  0.881591  0.362811
#
#             h         i         j
# ...

# %%
newdf2.reset_index(drop=True, inplace=True)

# %%
newdf2.head()
# Out:
#           a         b            c         d         e         f         g  \
# 0       0.3  0.589775     0.157341  0.809486  0.265164  0.951230  0.865672
# 1  0.993055  0.816023  2389.000000  0.435114  0.674062  0.933069  0.397244
# 2  0.878181  0.407539     0.277625  0.470148  0.915559  0.789691  0.614388
# 3   0.60274  0.921677     0.327032  0.223274  0.222496  0.822141  0.583255
# 4  0.179375  0.368591     0.813978  0.132293  0.724275  0.754739  0.865419
#
#           h         i         j
# 0  0.055177  0.869342  0.809105
# 1  0.643524  0.579457  0.835099
# 2  0.695804  0.627689  0.134094
# 3  0.855693  0.762797  0.263273
# 4  0.115947  0.173696  0.550884

# %%
newdf2.index = list(range(1,641,2))

# %%
newdf2
# Out:
#             a         b            c         d         e         f         g  \
# 1         0.3  0.589775     0.157341  0.809486  0.265164  0.951230  0.865672
# 3    0.993055  0.816023  2389.000000  0.435114  0.674062  0.933069  0.397244
# 5    0.878181  0.407539     0.277625  0.470148  0.915559  0.789691  0.614388
# 7     0.60274  0.921677     0.327032  0.223274  0.222496  0.822141  0.583255
# 9    0.179375  0.368591     0.813978  0.132293  0.724275  0.754739  0.865419
# ..        ...       ...          ...       ...       ...       ...       ...
# 631  0.225751  0.781242     0.410185  0.994910  0.900653  0.457395  0.985627
# 633  0.552878  0.624007     0.919886  0.343476  0.091060  0.035843  0.706981
# 635  0.288015  0.046701     0.313751  0.265766  0.757930  0.688525  0.383174
# 637  0.433425  0.329384     0.649478  0.510130  0.258696  0.769901  0.307465
# 639  0.047887  0.530913     0.529743  0.201659  0.159088  0.881591  0.362811
#
#             h         i         j
# ...

# %%
newdf4 = pd.DataFrame(np.random.rand(1,2))

# %%
newdf4.index
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
newdf4
# Out:
#          0         1
# 0  0.86274  0.326755

# %%
newdf4.index=[1]

# %%
newdf4
# Out:
#          0         1
# 1  0.86274  0.326755

# %%
newdf4.columns = list("12")

# %%
newdf4
# Out:
#          1         2
# 1  0.86274  0.326755

# %%
newdf4.columns = ["a","b"]

# %%
newdf4
# Out:
#          a         b
# 1  0.86274  0.326755

# %%
newdf4.sort_index(axis=1,ascending=False, inplace=True)

# %%
newdf4
# Out:
#           b        a
# 1  0.326755  0.86274

# %%
df = pd.DataFrame({"name":['Sommy','Swayam','Subin'],
                 "toy":[np.nan,'Batmobile','Bullwhip'],
                   "born":[pd.NaT,pd.Timestamp("1940-04-25"),pd.NaT]})
""""np.nan refers to a special floating-point value in the NumPy library, which stands for "Not a Number." It is used to 
represent missing or undefined data in numerical arrays. The nan value is typically used in situations where a particular
value is not available or cannot be represented, such as when there are data gaps, invalid calculations, or incomplete 
measurements."""
# Out:
# '"np.nan refers to a special floating-point value in the NumPy library, which stands for "Not a Number." It is used to \nrepresent missing or undefined data in numerical arrays. The nan value is typically used in situations where a particular\nvalue is not available or cannot be represented, such as when there are data gaps, invalid calculations, or incomplete \nmeasurements.'

# %%
"""
1.For the "name" column: Since the "name" column is of type object (string), using np.nan or pd.NaT would both represent 
missing values. In this case, there won't be any significant difference between them, and you can choose to use either one.

2.For the "toy" column: Since the "toy" column contains string values, using np.nan will work fine to represent missing values. 
However, if you intend to perform any numerical operations on this column (e.g., calculating statistics or applying mathematical functions), np.nan might cause data type conflicts or errors.

3.For the "born" column: This column contains datetime values. Here, it is recommended to use pd.NaT to represent missing dates 
instead of np.nan. pd.NaT is specifically designed to handle missing or undefined datetime values in pandas and provides 
appropriate functionalities for working with datetime data. Using np.nan in a datetime column may result in unexpected behavior
or errors when performing datetime operations."""
# Out:
# '\n1.For the "name" column: Since the "name" column is of type object (string), using np.nan or pd.NaT would both represent \nmissing values. In this case, there won\'t be any significant difference between them, and you can choose to use either one.\n\n2.For the "toy" column: Since the "toy" column contains string values, using np.nan will work fine to represent missing values. \nHowever, if you intend to perform any numerical operations on this column (e.g., calculating statistics or applying mathematical functions), np.nan might cause data type conflicts or errors.\n\n3.For the "born" column: This column contains datetime values. Here, it is recommended to use pd.NaT to represent missing dates \ninstead of np.nan. pd.NaT is specifically designed to handle missing or undefined datetime values in pandas and provides \nappropriate functionalities for working with datetime data. Using np.nan in a datetime column may result in unexpected behavior\nor errors when performing datetime ope
# ...

# %%
df.head()
# Out:
#      name        toy       born
# 0   Sommy        NaN        NaT
# 1  Swayam  Batmobile 1940-04-25
# 2   Subin   Bullwhip        NaT

# %%
df.dropna()
# Out:
#      name        toy       born
# 1  Swayam  Batmobile 1940-04-25

# %%
df.iloc[1,1] = np.nan

# %%
df.head()
# Out:
#      name       toy       born
# 0   Sommy       NaN        NaT
# 1  Swayam       NaN 1940-04-25
# 2   Subin  Bullwhip        NaT

# %%
df.iloc[2,1] = np.nan

# %%
df.head()
# Out:
#      name  toy       born
# 0   Sommy  NaN        NaT
# 1  Swayam  NaN 1940-04-25
# 2   Subin  NaN        NaT

# %%
df.dropna(how='all', axis = 1)
# Out:
#      name       born
# 0   Sommy        NaT
# 1  Swayam 1940-04-25
# 2   Subin        NaT

# %%
df.drop_duplicates(subset=None,keep='first',inplace=False)
# Out:
#      name  toy       born
# 0   Sommy  NaN        NaT
# 1  Swayam  NaN 1940-04-25
# 2   Subin  NaN        NaT

# %%
df.head()
# Out:
#      name  toy       born
# 0   Sommy  NaN        NaT
# 1  Swayam  NaN 1940-04-25
# 2   Subin  NaN        NaT

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   toy     0 non-null      object
#  2   born    1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 204.0+ bytes

# %%
newdf.info()
newdf1.info()
newdf2.info()
newdf3.info()
newdf4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 320 entries, 0 to 319
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       320 non-null    object
#  1   1       320 non-null    float64
#  2   2       320 non-null    float64
#  3   3       320 non-null    float64
#  4   4       320 non-null    float64
#  5   5       320 non-null    float64
#  6   6       320 non-null    float64
#  7   7       320 non-null    float64
#  8   8       320 non-null    float64
#  9   9       320 non-null    float64
# dtypes: float64(9), object(1)
# memory usage: 32.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       200 non-null    float64
#  1   1       200 non-null    float64
#  2   2       200 non-null    float64
#  3   3       200 non-null    float64
# ...

# %%
newdf3[3].value_counts(dropna=True)
#.value_counts() gives us the number of a particular data in a column
# Out:
# 3
# 0.478752    1
# 0.617820    1
# 0.453814    1
# 0.598402    1
# 0.160818    1
# 0.341373    1
# 0.774178    1
# 0.156933    1
# 0.048579    1
# 0.605567    1
# Name: count, dtype: int64

# %%
df['born'].value_counts(dropna=False)
# Out:
# born
# NaT           2
# 1940-04-25    1
# Name: count, dtype: int64

# %%
df.notnull()
# Out:
#    name    toy   born
# 0  True  False  False
# 1  True  False   True
# 2  True  False  False

# %%
df.isnull()
# Out:
#     name   toy   born
# 0  False  True   True
# 1  False  True  False
# 2  False  True   True

# %%
adf = pd.DataFrame(np.random.rand(3,2))

# %%
adf.head()
# Out:
#           0         1
# 0  0.859443  0.884298
# 1  0.652637  0.532242
# 2  0.935120  0.739947

# %%
adf.std()
# Out:
# 0    0.146226
# 1    0.176975
# dtype: float64

# %%
adf.describe()
# Out:
#               0         1
# count  3.000000  3.000000
# mean   0.815733  0.718829
# std    0.146226  0.176975
# min    0.652637  0.532242
# 25%    0.756040  0.636094
# 50%    0.859443  0.739947
# 75%    0.897281  0.812122
# max    0.935120  0.884298

# %%
adf.corr()
# Out:
#           0         1
# 0  1.000000  0.776427
# 1  0.776427  1.000000

# %%
adf.count()
# Out:
# 0    3
# 1    3
# dtype: int64

# %%
excel_df = pd.DataFrame({"name":['sommy','pommy','lommy','chaite','soyam'],"grade":['a','b','c','D','e']})

# %%
excel_df.to_excel('example.xlsx',index=False)

# %%
pd.read_excel('example.xlsx')
# Out:
#      name grade
# 0   sommy     a
# 1   pommy     b
# 2   lommy     c
# 3  chaite     D
# 4   soyam     e
